# %% [markdown]
# # Reading Files In Pandas

# %%
import pandas as pd

# %%
#Reading a CSV file
df = pd.read_csv(r"C:\Users\user\Downloads\countries of the world.csv")
df
# Out:
#              Country                               Region
# 0       Afghanistan         ASIA (EX. NEAR EAST)
# 1           Albania   EASTERN EUROPE
# 2           Algeria   NORTHERN AFRICA
# 3    American Samoa   OCEANIA
# 4           Andorra   WESTERN EUROPE
# ..               ...                                  ...
# 222       West Bank   NEAR EAST
# 223  Western Sahara   NORTHERN AFRICA
# 224           Yemen   NEAR EAST
# 225          Zambia   SUB-SAHARAN AFRICA
# 226        Zimbabwe   SUB-SAHARAN AFRICA
#
# [227 rows x 2 columns]

# %%
#Reading a Text file
df = pd.read_table(r"C:\Users\user\Downloads\countries of the world.txt")
df
# Out:
#              Country                               Region
# 0       Afghanistan         ASIA (EX. NEAR EAST)
# 1           Albania   EASTERN EUROPE
# 2           Algeria   NORTHERN AFRICA
# 3    American Samoa   OCEANIA
# 4           Andorra   WESTERN EUROPE
# ..               ...                                  ...
# 222       West Bank   NEAR EAST
# 223  Western Sahara   NORTHERN AFRICA
# 224           Yemen   NEAR EAST
# 225          Zambia   SUB-SAHARAN AFRICA
# 226        Zimbabwe   SUB-SAHARAN AFRICA
#
# [227 rows x 2 columns]

# %%
#Reading JSON files
df = pd.read_json(r"C:\Users\user\Downloads\json_sample.json")
df
# Out:
#                                            12 Strong  ...  \
# 0  {'Genre': 'Action', 'Gross': '$453,173', 'IMDB...  ...
#
#                                           Winchester
# 0  {'Genre': 'Biography', 'Gross': '$696,786', 'I...
#
# [1 rows x 38 columns]

# %%
#Reading Excel files
df = pd.read_excel(r"C:\Users\user\Downloads\world_population_excel_workbook.xlsx")
df
# Out:
#      Rank  ... World Population Percentage
# 0      36  ...                        0.52
# 1     138  ...                        0.04
# 2      34  ...                        0.56
# 3     213  ...                        0.00
# 4     203  ...                        0.00
# ..    ...  ...                         ...
# 229   226  ...                        0.00
# 230   172  ...                        0.01
# 231    46  ...                        0.42
# 232    63  ...                        0.25
# 233    74  ...                        0.20
#
# [234 rows x 17 columns]

# %%
#Reading a different Excel sheet
df2 = pd.read_excel(r"C:\Users\user\Downloads\world_population_excel_workbook.xlsx", sheet_name = 'Sheet1')
df2
# Out:
#      Rank  ...           Capital
# 0      36  ...             Kabul
# 1     138  ...            Tirana
# 2      34  ...           Algiers
# 3     213  ...         Pago Pago
# 4     203  ...  Andorra la Vella
# ..    ...  ...               ...
# 229   226  ...          Mata-Utu
# 230   172  ...         El AaiÃºn
# 231    46  ...             Sanaa
# 232    63  ...            Lusaka
# 233    74  ...            Harare
#
# [234 rows x 4 columns]

# %%
# getting a sneak pic into your data
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Rank     234 non-null    int64
#  1   CCA3     234 non-null    object
#  2   Country  234 non-null    object
#  3   Capital  234 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 7.4+ KB

# %%
df2.shape
# Out:
# (234, 4)

# %%
df2.head()
# Out:
#    Rank  ...           Capital
# 0    36  ...             Kabul
# 1   138  ...            Tirana
# 2    34  ...           Algiers
# 3   213  ...         Pago Pago
# 4   203  ...  Andorra la Vella
#
# [5 rows x 4 columns]

# %%
df2.head(n = 11)
# Out:
#     Rank  ...           Capital
# 0     36  ...             Kabul
# 1    138  ...            Tirana
# 2     34  ...           Algiers
# 3    213  ...         Pago Pago
# 4    203  ...  Andorra la Vella
# 5     42  ...            Luanda
# 6    224  ...        The Valley
# 7    201  ...    Saint Johnâ€™s
# 8     33  ...      Buenos Aires
# 9    140  ...           Yerevan
# 10   198  ...        Oranjestad
#
# [11 rows x 4 columns]

# %%
#Calling out a specific column
df2['Rank']
# Out:
# 0       36
# 1      138
# 2       34
# 3      213
# 4      203
#       ...
# 229    226
# 230    172
# 231     46
# 232     63
# 233     74
# Name: Rank, Length: 234, dtype: int64

# %%
df2.loc[224]
# Out:
# Rank               43
# CCA3              UZB
# Country    Uzbekistan
# Capital      Tashkent
# Name: 224, dtype: object

# %%
df2.iloc[224]
# Out:
# Rank               43
# CCA3              UZB
# Country    Uzbekistan
# Capital      Tashkent
# Name: 224, dtype: object

# %% [markdown]
# # Filtering Columns and Rows in Pandas

# %%
print(df2)
# Out:
#      Rank  ...           Capital
# 0      36  ...             Kabul
# 1     138  ...            Tirana
# 2      34  ...           Algiers
# 3     213  ...         Pago Pago
# 4     203  ...  Andorra la Vella
# ..    ...  ...               ...
# 229   226  ...          Mata-Utu
# 230   172  ...         El AaiÃºn
# 231    46  ...             Sanaa
# 232    63  ...            Lusaka
# 233    74  ...            Harare
#
# [234 rows x 4 columns]

# %%
world_pop = pd.read_csv(r"C:\Users\user\Downloads\world_population.csv")
world_pop
# Out:
#      Rank  ... World Population Percentage
# 0      36  ...                        0.52
# 1     138  ...                        0.04
# 2      34  ...                        0.56
# 3     213  ...                        0.00
# 4     203  ...                        0.00
# ..    ...  ...                         ...
# 229   226  ...                        0.00
# 230   172  ...                        0.01
# 231    46  ...                        0.42
# 232    63  ...                        0.25
# 233    74  ...                        0.20
#
# [234 rows x 17 columns]

# %%
world_pop[world_pop['Rank']<10]
# Out:
#      Rank  ... World Population Percentage
# 16      8  ...                        2.15
# 27      7  ...                        2.70
# 41      1  ...                       17.88
# 92      2  ...                       17.77
# 93      4  ...                        3.45
# 149     6  ...                        2.74
# 156     5  ...                        2.96
# 171     9  ...                        1.81
# 221     3  ...                        4.24
#
# [9 rows x 17 columns]

# %%
specific_countries = ['Bangladesh', 'Brazil']

world_pop[world_pop['Country'].isin(specific_countries)]
# Out:
#     Rank  ... World Population Percentage
# 16     8  ...                        2.15
# 27     7  ...                        2.70
#
# [2 rows x 17 columns]

# %%
world_pop[world_pop['Country'].str.contains('United')]
# Out:
#      Rank  ... World Population Percentage
# 219    97  ...                        0.12
# 220    21  ...                        0.85
# 221     3  ...                        4.24
# 222   200  ...                        0.00
#
# [4 rows x 17 columns]

# %%
world_pop.loc[3]
# Out:
# Rank                                      213
# CCA3                                      ASM
# Country                        American Samoa
# Capital                             Pago Pago
# Continent                             Oceania
# 2022 Population                       44273.0
# 2020 Population                       46189.0
# 2015 Population                       51368.0
# 2010 Population                       54849.0
# 2000 Population                       58230.0
# 1990 Population                       47818.0
# 1980 Population                       32886.0
# 1970 Population                       27075.0
# Area (km²)                              199.0
# Density (per km²)                    222.4774
# Growth Rate                            0.9831
# World Population Percentage               0.0
# Name: 3, dtype: object

# %%
world_pop[world_pop['Rank']<10].sort_values(by='Rank')
# Out:
#      Rank  ... World Population Percentage
# 41      1  ...                       17.88
# 92      2  ...                       17.77
# 221     3  ...                        4.24
# 93      4  ...                        3.45
# 156     5  ...                        2.96
# 149     6  ...                        2.74
# 27      7  ...                        2.70
# 16      8  ...                        2.15
# 171     9  ...                        1.81
#
# [9 rows x 17 columns]

# %%
world_pop
# Out:
#      Rank  ... World Population Percentage
# 0      36  ...                        0.52
# 1     138  ...                        0.04
# 2      34  ...                        0.56
# 3     213  ...                        0.00
# 4     203  ...                        0.00
# ..    ...  ...                         ...
# 229   226  ...                        0.00
# 230   172  ...                        0.01
# 231    46  ...                        0.42
# 232    63  ...                        0.25
# 233    74  ...                        0.20
#
# [234 rows x 17 columns]

# %%
world_pop.reset_index(inplace = True)
world_pop
# Out:
#      index  ...  World Population Percentage
# 0        0  ...                         0.52
# 1        1  ...                         0.04
# 2        2  ...                         0.56
# 3        3  ...                         0.00
# 4        4  ...                         0.00
# ..     ...  ...                          ...
# 229    229  ...                         0.00
# 230    230  ...                         0.01
# 231    231  ...                         0.42
# 232    232  ...                         0.25
# 233    233  ...                         0.20
#
# [234 rows x 18 columns]

# %%
df = pd.read_csv(r"C:\Users\user\Downloads\Flavors.csv")
df
# Out:
#                    Flavor Base Flavor Liked  Flavor Rating  Texture Rating  \
# 0     Mint Chocolate Chip     Vanilla   Yes           10.0             8.0
# 1               Chocolate   Chocolate   Yes            8.8             7.6
# 2                 Vanilla     Vanilla    No            4.7             5.0
# 3            Cookie Dough     Vanilla   Yes            6.9             6.5
# 4              Rocky Road   Chocolate   Yes            8.2             7.0
# 5               Pistachio     Vanilla    No            2.3             3.4
# 6             Cake Batter     Vanilla   Yes            6.5             6.0
# 7              Neapolitan     Vanilla    No            3.8             5.0
# 8  Chocolte Fudge Brownie   Chocolate   Yes            8.2             7.1
#
#    Total Rating
# 0          18.0
# 1          16.6
# 2           9.7
# 3          13.4
# 4          15.2
# 5           5.7
# 6          12.5
# 7           8.8
# 8          15.3

# %%
#When displaying all the rows and columns in a df
pd.set_option('display.max.rows',9)
pd.set_option('display.max.columns', 6)

# %%
grouped_data = df.groupby('Base Flavor')

# %%
grouped_data

# %%
grouped_data.mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1942, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1941 try:
# -> 1942     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943 except Exception as err:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:864, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     862     preserve_dtype = True
# --> 864 result = self._aggregate_series_pure_python(obj, func)
#     866 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:885, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     884 for i, group in enumerate(splitter):
# --> 885     res = func(group)
# ...
